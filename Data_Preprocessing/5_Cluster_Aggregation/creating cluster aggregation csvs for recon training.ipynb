# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/MyDrive/FYP_Python_Notebooks')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
df_outf = pd.read_csv('combined_demand_df_1h.csv')
df_outf = df_outf.drop('time_slot', axis=1)

df_inf = pd.read_csv('combined_supply_df_1h.csv')
df_inf = df_inf.drop('time_slot', axis=1)

if(df_outf.shape[0] != df_inf.shape[0]): # check if dem and inf are same length
    print("outflow and inflow are NOT of same length")
    sys.exit()

# %%
cluster_zones = {
    '238': ['113', '137', '153', '164', '166', '194', '236', '237', '238'],
    '50': ['50', '144', '186', '209', '224', '230', '243', '244', '262', '263'],
    '120': ['4', '114', '120', '148', '158'],
    '232': ['24', '41', '42', '100', '116', '127', '128', '152', '211', '232'],
    '141': ['12', '13', '68', '87', '140', '141', '142', '229', '231', '233'],
    '151': ['143', '151', '161'],
    '246': ['48', '90', '107', '162', '170', '246'],
    '239': ['43', '75', '88', '163', '234', '239', '261'],
    '74': ['45', '74', '79', '202'],
    '125': ['125', '249']}

# %%
for cluster, zones in cluster_zones.items():
    df_outf_cluster = df_outf[zones]
    df_outf_cluster['aggregated_sum'] = df_outf_cluster.sum(axis=1)
    df_outf_cluster.to_csv("cluster_" + cluster + "_demand_for_recon_training.csv")
# Out:
# <ipython-input-7-0b56371b8b36>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_outf_cluster['aggregated_sum'] = df_outf_cluster.sum(axis=1)
# <ipython-input-7-0b56371b8b36>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_outf_cluster['aggregated_sum'] = df_outf_cluster.sum(axis=1)
# <ipython-input-7-0b56371b8b36>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
zones = ['113', '137', '153', '164', '166', '194', '236', '237', '238']

df_outf_cluster = df_outf[zones]
df_outf_cluster['aggregated_sum'] = df_outf_cluster.sum(axis=1)

df_outf_cluster
# Out:
# <ipython-input-6-648cf07100ab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_outf_cluster['aggregated_sum'] = df_outf_cluster.sum(axis=1)
#          113   137  153    164   166  194    236    237    238  aggregated_sum
# 0       17.0  23.0  0.0   25.0   9.0  0.0   35.0   35.0   39.0           183.0
# 1       21.0  32.0  0.0   24.0  10.0  0.0   30.0   16.0   27.0           160.0
# 2       15.0  22.0  0.0   20.0   5.0  0.0   12.0   17.0   23.0           114.0
# 3        2.0   6.0  0.0   11.0   1.0  0.0    3.0    7.0   10.0            40.0
# 4        2.0   6.0  0.0    5.0   0.0  0.0    1.0    2.0    4.0            20.0
# ...      ...   ...  ...    ...   ...  ...    ...    ...    ...             ...
# ...

# %%
os.chdir('/content/drive/MyDrive/FYP_Python_Notebooks/Data_for_Reconciliation_Training/Cluster_Aggregation_Recon')
c50 = pd.read_csv("cluster_50_demand_for_recon_training.csv")
# Out:
#        Unnamed: 0    50   144    186   209  224    230  243  244   262    263  \
# 0               0   7.0   4.0   19.0   3.0  3.0   59.0  0.0  2.0  15.0   54.0
# 1               1  20.0   5.0   29.0   2.0  5.0   48.0  1.0  3.0  18.0   49.0
# 2               2  14.0   8.0   26.0   4.0  4.0   29.0  0.0  3.0   7.0   27.0
# 3               3   5.0   3.0   17.0   2.0  0.0   16.0  0.0  1.0   2.0   12.0
# 4               4   8.0   2.0   11.0   0.0  0.0    6.0  0.0  2.0   1.0   10.0
# ...           ...   ...   ...    ...   ...  ...    ...  ...  ...   ...    ...
# 24808       24808  26.0  41.0  149.0   7.0  3.0  190.0  1.0  0.0  80.0  126.0
# 24809       24809  19.0  49.0  126.0  11.0  7.0  197.0  1.0  1.0  67.0  112.0
# 24810       24810  26.0  68.0   94.0   9.0  2.0  266.0  0.0  0.0  35.0   99.0
# 24811       24811  24.0  64.0  112.0   5.0  9.0  206.0  0.0  0.0  21.0   60.0
# 24812       24812  17.0  62.0   76.0   4.0  4.0  131.0  0.0  2.0  12.0   50.0
#
#        aggregated_sum
# ...

# %%
c50 = c50.drop(columns=["Unnamed: 0"])
c50
# Out:
#          50   144    186   209  224    230  243  244   262    263  \
# 0       7.0   4.0   19.0   3.0  3.0   59.0  0.0  2.0  15.0   54.0
# 1      20.0   5.0   29.0   2.0  5.0   48.0  1.0  3.0  18.0   49.0
# 2      14.0   8.0   26.0   4.0  4.0   29.0  0.0  3.0   7.0   27.0
# 3       5.0   3.0   17.0   2.0  0.0   16.0  0.0  1.0   2.0   12.0
# 4       8.0   2.0   11.0   0.0  0.0    6.0  0.0  2.0   1.0   10.0
# ...     ...   ...    ...   ...  ...    ...  ...  ...   ...    ...
# 24808  26.0  41.0  149.0   7.0  3.0  190.0  1.0  0.0  80.0  126.0
# 24809  19.0  49.0  126.0  11.0  7.0  197.0  1.0  1.0  67.0  112.0
# 24810  26.0  68.0   94.0   9.0  2.0  266.0  0.0  0.0  35.0   99.0
# 24811  24.0  64.0  112.0   5.0  9.0  206.0  0.0  0.0  21.0   60.0
# 24812  17.0  62.0   76.0   4.0  4.0  131.0  0.0  2.0  12.0   50.0
#
#        aggregated_sum
# 0               166.0
# 1               180.0
# 2               122.0
# 3                58.0
# 4                40.0
# ...               ...
# ...

# %%
c74 = pd.read_csv("cluster_74_demand_for_recon_training.csv")
c74
# Out:
#        Unnamed: 0    45    74     79  202  aggregated_sum
# 0               0   4.0  19.0   21.0  0.0            44.0
# 1               1   0.0  27.0   46.0  0.0            73.0
# 2               2   0.0  13.0   34.0  1.0            48.0
# 3               3   1.0   8.0   19.0  0.0            28.0
# 4               4   0.0   5.0   13.0  0.0            18.0
# ...           ...   ...   ...    ...  ...             ...
# 24808       24808  12.0   9.0  104.0  0.0           125.0
# 24809       24809   7.0   4.0  126.0  1.0           138.0
# 24810       24810   7.0   6.0  158.0  0.0           171.0
# 24811       24811  11.0   6.0  201.0  0.0           218.0
# 24812       24812  11.0   4.0  181.0  0.0           196.0
#
# [24813 rows x 6 columns]

# %%
c74 = c74.drop(columns=["Unnamed: 0"])
c74
# Out:
#          45    74     79  202  aggregated_sum
# 0       4.0  19.0   21.0  0.0            44.0
# 1       0.0  27.0   46.0  0.0            73.0
# 2       0.0  13.0   34.0  1.0            48.0
# 3       1.0   8.0   19.0  0.0            28.0
# 4       0.0   5.0   13.0  0.0            18.0
# ...     ...   ...    ...  ...             ...
# 24808  12.0   9.0  104.0  0.0           125.0
# 24809   7.0   4.0  126.0  1.0           138.0
# 24810   7.0   6.0  158.0  0.0           171.0
# 24811  11.0   6.0  201.0  0.0           218.0
# 24812  11.0   4.0  181.0  0.0           196.0
#
# [24813 rows x 5 columns]

# %%
c120 = pd.read_csv("cluster_120_demand_for_recon_training.csv")
c120
# Out:
#        Unnamed: 0    4    114  120   148   158  aggregated_sum
# 0               0  3.0    8.0  0.0   9.0   5.0            25.0
# 1               1  1.0   10.0  0.0  12.0   5.0            28.0
# 2               2  2.0   11.0  0.0  11.0   6.0            30.0
# 3               3  3.0    8.0  0.0   9.0   2.0            22.0
# 4               4  0.0    1.0  0.0   1.0   1.0             3.0
# ...           ...  ...    ...  ...   ...   ...             ...
# 24808       24808  2.0   41.0  0.0  28.0  39.0           110.0
# 24809       24809  5.0   45.0  0.0  35.0  47.0           132.0
# 24810       24810  3.0   73.0  0.0  52.0  63.0           191.0
# 24811       24811  9.0   80.0  0.0  62.0  58.0           209.0
# 24812       24812  8.0  101.0  0.0  77.0  60.0           246.0
#
# [24813 rows x 7 columns]

# %%
c120 = c120.drop(columns=["Unnamed: 0"])
c120
# Out:
#          4    114  120   148   158  aggregated_sum
# 0      3.0    8.0  0.0   9.0   5.0            25.0
# 1      1.0   10.0  0.0  12.0   5.0            28.0
# 2      2.0   11.0  0.0  11.0   6.0            30.0
# 3      3.0    8.0  0.0   9.0   2.0            22.0
# 4      0.0    1.0  0.0   1.0   1.0             3.0
# ...    ...    ...  ...   ...   ...             ...
# 24808  2.0   41.0  0.0  28.0  39.0           110.0
# 24809  5.0   45.0  0.0  35.0  47.0           132.0
# 24810  3.0   73.0  0.0  52.0  63.0           191.0
# 24811  9.0   80.0  0.0  62.0  58.0           209.0
# 24812  8.0  101.0  0.0  77.0  60.0           246.0
#
# [24813 rows x 6 columns]

# %%
c125 = pd.read_csv("cluster_125_demand_for_recon_training.csv")
c125
# Out:
#        Unnamed: 0   125    249  aggregated_sum
# 0               0   4.0   20.0            24.0
# 1               1   9.0   32.0            41.0
# 2               2   8.0   17.0            25.0
# 3               3   2.0   10.0            12.0
# 4               4   0.0    3.0             3.0
# ...           ...   ...    ...             ...
# 24808       24808  26.0  147.0           173.0
# 24809       24809  22.0  159.0           181.0
# 24810       24810  37.0  184.0           221.0
# 24811       24811  27.0  190.0           217.0
# 24812       24812  27.0  272.0           299.0
#
# [24813 rows x 4 columns]

# %%
c125 = c125.drop(columns=["Unnamed: 0"])
c125
# Out:
#         125    249  aggregated_sum
# 0       4.0   20.0            24.0
# 1       9.0   32.0            41.0
# 2       8.0   17.0            25.0
# 3       2.0   10.0            12.0
# 4       0.0    3.0             3.0
# ...     ...    ...             ...
# 24808  26.0  147.0           173.0
# 24809  22.0  159.0           181.0
# 24810  37.0  184.0           221.0
# 24811  27.0  190.0           217.0
# 24812  27.0  272.0           299.0
#
# [24813 rows x 3 columns]

# %%
c141 = pd.read_csv("cluster_141_demand_for_recon_training.csv")
c141 = c141.drop(columns=["Unnamed: 0"])
c141
# Out:
#         12    13     68    87    140    141    142    229   231   233  \
# 0      0.0   3.0   27.0   6.0   19.0   39.0   37.0   17.0  12.0  13.0
# 1      0.0   2.0   30.0   7.0   14.0   50.0   47.0   30.0  22.0  10.0
# 2      0.0   2.0   27.0   7.0    7.0   21.0   24.0   17.0  14.0  13.0
# 3      0.0   0.0   16.0   6.0    2.0   13.0   12.0    8.0  14.0   5.0
# 4      0.0   0.0    5.0   1.0    2.0    5.0    7.0    4.0   1.0   6.0
# ...    ...   ...    ...   ...    ...    ...    ...    ...   ...   ...
# 24808  0.0  37.0  154.0  32.0  124.0  191.0  270.0  118.0  89.0  77.0
# 24809  0.0  37.0  149.0  30.0   86.0  180.0  250.0   85.0  83.0  57.0
# 24810  0.0  27.0  140.0  31.0   71.0  103.0  290.0  100.0  77.0  52.0
# 24811  0.0  14.0  151.0  13.0   55.0   94.0  179.0   74.0  68.0  44.0
# 24812  1.0   9.0   88.0  17.0   36.0   40.0  213.0   61.0  49.0  22.0
#
#        aggregated_sum
# 0               173.0
# 1               212.0
# 2               132.0
# 3                76.0
# ...

# %%
c151 = pd.read_csv("cluster_151_demand_for_recon_training.csv")
c151 = c151.drop(columns=["Unnamed: 0"])
c151
# Out:
#         143   151    161  aggregated_sum
# 0      11.0  22.0   41.0            74.0
# 1      13.0  22.0   33.0            68.0
# 2      10.0   8.0   24.0            42.0
# 3       1.0   5.0   11.0            17.0
# 4       3.0   1.0    3.0             7.0
# ...     ...   ...    ...             ...
# 24808  75.0  69.0  384.0           528.0
# 24809  52.0  44.0  339.0           435.0
# 24810  33.0  22.0  341.0           396.0
# 24811  26.0  20.0  229.0           275.0
# 24812  11.0   8.0  107.0           126.0
#
# [24813 rows x 4 columns]

# %%
c232 = pd.read_csv("cluster_232_demand_for_recon_training.csv")
c232 = c232.drop(columns=["Unnamed: 0"])
c232
# Out:
#          24    41    42   100  116  127  128  152   211  232  aggregated_sum
# 0       7.0   5.0   2.0  35.0  2.0  1.0  0.0  0.0   5.0  2.0            59.0
# 1       4.0  22.0  14.0  34.0  4.0  3.0  0.0  6.0   9.0  6.0           102.0
# 2       2.0  11.0   9.0  19.0  2.0  2.0  0.0  1.0   3.0  8.0            57.0
# 3       2.0   3.0   7.0  12.0  5.0  0.0  0.0  3.0   2.0  1.0            35.0
# 4       2.0   8.0   4.0   5.0  2.0  0.0  0.0  2.0   0.0  1.0            24.0
# ...     ...   ...   ...   ...  ...  ...  ...  ...   ...  ...             ...
# 24808   6.0  27.0   4.0  81.0  1.0  0.0  0.0  5.0  17.0  4.0           145.0
# 24809  10.0  12.0   1.0  67.0  0.0  0.0  0.0  0.0  14.0  8.0           112.0
# 24810  10.0   4.0   4.0  56.0  3.0  0.0  1.0  5.0  24.0  3.0           110.0
# 24811   9.0  12.0   4.0  62.0  2.0  1.0  0.0  0.0  51.0  2.0           143.0
# 24812   3.0   2.0   4.0  35.0  2.0  1.0  0.0  1.0  69.0  4.0           121.0
#
# [24813 rows x 11 columns]

# %%
c238 = pd.read_csv("cluster_238_demand_for_recon_training.csv")
c238 = c238.drop(columns=["Unnamed: 0"])
c238
# Out:
#          113   137  153    164   166  194    236    237    238  aggregated_sum
# 0       17.0  23.0  0.0   25.0   9.0  0.0   35.0   35.0   39.0           183.0
# 1       21.0  32.0  0.0   24.0  10.0  0.0   30.0   16.0   27.0           160.0
# 2       15.0  22.0  0.0   20.0   5.0  0.0   12.0   17.0   23.0           114.0
# 3        2.0   6.0  0.0   11.0   1.0  0.0    3.0    7.0   10.0            40.0
# 4        2.0   6.0  0.0    5.0   0.0  0.0    1.0    2.0    4.0            20.0
# ...      ...   ...  ...    ...   ...  ...    ...    ...    ...             ...
# 24808  117.0  70.0  0.0  127.0  34.0  0.0  392.0  339.0  179.0          1258.0
# 24809  127.0  45.0  0.0  118.0  27.0  0.0  275.0  394.0  119.0          1105.0
# 24810  127.0  51.0  0.0   97.0  26.0  0.0  162.0  281.0   76.0           820.0
# 24811  129.0  48.0  0.0   97.0  18.0  0.0  108.0  183.0   36.0           619.0
# 24812  164.0  37.0  0.0   68.0   3.0  0.0   27.0   96.0   25.0           420.0
#
# ...

# %%
c239 = pd.read_csv("cluster_239_demand_for_recon_training.csv")
c239 = c239.drop(columns=["Unnamed: 0"])
c239
# Out:
#          43    75    88    163    234    239   261  aggregated_sum
# 0      22.0  22.0   1.0   16.0   22.0   28.0   2.0           113.0
# 1       6.0  14.0   2.0   21.0   18.0   44.0   6.0           111.0
# 2       5.0  13.0   2.0   13.0   25.0   21.0   5.0            84.0
# 3       2.0   7.0   1.0    7.0    7.0    8.0   1.0            33.0
# 4       0.0   8.0   1.0    0.0    5.0    6.0   2.0            22.0
# ...     ...   ...   ...    ...    ...    ...   ...             ...
# 24808  51.0  41.0  19.0  200.0  185.0  199.0  23.0           718.0
# 24809  88.0  31.0  14.0  203.0  158.0  191.0  26.0           711.0
# 24810  49.0  21.0   7.0  183.0  217.0  176.0  16.0           669.0
# 24811  37.0  12.0  12.0  177.0  232.0   94.0  12.0           576.0
# 24812  29.0   5.0  11.0   93.0  151.0   50.0   7.0           346.0
#
# [24813 rows x 8 columns]

# %%
c246 = pd.read_csv("cluster_246_demand_for_recon_training.csv")
c246 = c246.drop(columns=["Unnamed: 0"])
c246
# Out:
#           48     90    107    162    170    246  aggregated_sum
# 0       81.0   18.0   32.0   19.0   23.0    9.0           182.0
# 1       72.0   28.0   21.0   16.0   48.0   12.0           197.0
# 2       63.0   16.0   25.0   12.0   46.0   13.0           175.0
# 3       31.0   13.0   19.0    4.0   12.0    3.0            82.0
# 4       20.0    4.0    5.0    2.0   12.0    4.0            47.0
# ...      ...    ...    ...    ...    ...    ...             ...
# 24808  140.0  100.0  115.0  259.0  218.0  105.0           937.0
# 24809  128.0  103.0  134.0  245.0  181.0   93.0           884.0
# 24810  161.0  147.0  158.0  168.0  121.0   88.0           843.0
# 24811  175.0  156.0  128.0  116.0  107.0   53.0           735.0
# 24812  141.0   97.0   95.0   63.0   61.0   53.0           510.0
#
# [24813 rows x 7 columns]

# %%
os.chdir('/content/drive/MyDrive/FYP_Python_Notebooks/Data_for_Reconciliation_Training/POI_Aggregation_Recon')
attractions = pd.read_csv("attractions_demand_for_recon_training.csv")
attractions = attractions.drop(columns=["Unnamed: 0"])
attractions
# Out:
#          4   12    13    45     48    50    75     79    87    113  ...   137  \
# 0      3.0  0.0   3.0   4.0   81.0   7.0  22.0   21.0   6.0   17.0  ...  23.0
# 1      1.0  0.0   2.0   0.0   72.0  20.0  14.0   46.0   7.0   21.0  ...  32.0
# 2      2.0  0.0   2.0   0.0   63.0  14.0  13.0   34.0   7.0   15.0  ...  22.0
# 3      3.0  0.0   0.0   1.0   31.0   5.0   7.0   19.0   6.0    2.0  ...   6.0
# 4      0.0  0.0   0.0   0.0   20.0   8.0   8.0   13.0   1.0    2.0  ...   6.0
# ...    ...  ...   ...   ...    ...   ...   ...    ...   ...    ...  ...   ...
# 24808  2.0  0.0  37.0  12.0  140.0  26.0  41.0  104.0  32.0  117.0  ...  70.0
# 24809  5.0  0.0  37.0   7.0  128.0  19.0  31.0  126.0  30.0  127.0  ...  45.0
# 24810  3.0  0.0  27.0   7.0  161.0  26.0  21.0  158.0  31.0  127.0  ...  51.0
# 24811  9.0  0.0  14.0  11.0  175.0  24.0  12.0  201.0  13.0  129.0  ...  48.0
# 24812  8.0  1.0   9.0  11.0  141.0  17.0   5.0  181.0  17.0  164.0  ...  37.0
#
# ...

# %%
food_bar = pd.read_csv("food_bar_demand_for_recon_training.csv")
food_bar = food_bar.drop(columns=["Unnamed: 0"])
food_bar
# Out:
#          4    13    45     48    50     79    88   100   125  127  ...    230  \
# 0      3.0   3.0   4.0   81.0   7.0   21.0   1.0  35.0   4.0  1.0  ...   59.0
# 1      1.0   2.0   0.0   72.0  20.0   46.0   2.0  34.0   9.0  3.0  ...   48.0
# 2      2.0   2.0   0.0   63.0  14.0   34.0   2.0  19.0   8.0  2.0  ...   29.0
# 3      3.0   0.0   1.0   31.0   5.0   19.0   1.0  12.0   2.0  0.0  ...   16.0
# 4      0.0   0.0   0.0   20.0   8.0   13.0   1.0   5.0   0.0  0.0  ...    6.0
# ...    ...   ...   ...    ...   ...    ...   ...   ...   ...  ...  ...    ...
# 24808  2.0  37.0  12.0  140.0  26.0  104.0  19.0  81.0  26.0  0.0  ...  190.0
# 24809  5.0  37.0   7.0  128.0  19.0  126.0  14.0  67.0  22.0  0.0  ...  197.0
# 24810  3.0  27.0   7.0  161.0  26.0  158.0   7.0  56.0  37.0  0.0  ...  266.0
# 24811  9.0  14.0  11.0  175.0  24.0  201.0  12.0  62.0  27.0  1.0  ...  206.0
# 24812  8.0   9.0  11.0  141.0  17.0  181.0  11.0  35.0  27.0  1.0  ...  131.0
#
# ...

# %%
food = pd.read_csv("food_demand_for_recon_training.csv")
food = food.drop(columns=["Unnamed: 0"])
food
# Out:
#          4    13    41    42    45     48    50     79    87    88  ...  \
# 0      3.0   3.0   5.0   2.0   4.0   81.0   7.0   21.0   6.0   1.0  ...
# 1      1.0   2.0  22.0  14.0   0.0   72.0  20.0   46.0   7.0   2.0  ...
# 2      2.0   2.0  11.0   9.0   0.0   63.0  14.0   34.0   7.0   2.0  ...
# 3      3.0   0.0   3.0   7.0   1.0   31.0   5.0   19.0   6.0   1.0  ...
# 4      0.0   0.0   8.0   4.0   0.0   20.0   8.0   13.0   1.0   1.0  ...
# ...    ...   ...   ...   ...   ...    ...   ...    ...   ...   ...  ...
# 24808  2.0  37.0  27.0   4.0  12.0  140.0  26.0  104.0  32.0  19.0  ...
# 24809  5.0  37.0  12.0   1.0   7.0  128.0  19.0  126.0  30.0  14.0  ...
# 24810  3.0  27.0   4.0   4.0   7.0  161.0  26.0  158.0  31.0   7.0  ...
# 24811  9.0  14.0  12.0   4.0  11.0  175.0  24.0  201.0  13.0  12.0  ...
# 24812  8.0   9.0   2.0   4.0  11.0  141.0  17.0  181.0  17.0  11.0  ...
#
#          234    238    239  243  244    249   261   262    263    food
# ...

# %%
food_morning = pd.read_csv("food_morning_demand_for_recon_training.csv")
food_morning = food_morning.drop(columns=["Unnamed: 0"])
food_morning
# Out:
#          13     48    50     79    87    114    140    141    142   144  ...  \
# 0       3.0   81.0   7.0   21.0   6.0    8.0   19.0   39.0   37.0   4.0  ...
# 1       2.0   72.0  20.0   46.0   7.0   10.0   14.0   50.0   47.0   5.0  ...
# 2       2.0   63.0  14.0   34.0   7.0   11.0    7.0   21.0   24.0   8.0  ...
# 3       0.0   31.0   5.0   19.0   6.0    8.0    2.0   13.0   12.0   3.0  ...
# 4       0.0   20.0   8.0   13.0   1.0    1.0    2.0    5.0    7.0   2.0  ...
# ...     ...    ...   ...    ...   ...    ...    ...    ...    ...   ...  ...
# 24808  37.0  140.0  26.0  104.0  32.0   41.0  124.0  191.0  270.0  41.0  ...
# 24809  37.0  128.0  19.0  126.0  30.0   45.0   86.0  180.0  250.0  49.0  ...
# 24810  27.0  161.0  26.0  158.0  31.0   73.0   71.0  103.0  290.0  68.0  ...
# 24811  14.0  175.0  24.0  201.0  13.0   80.0   55.0   94.0  179.0  64.0  ...
# 24812   9.0  141.0  17.0  181.0  17.0  101.0   36.0   40.0  213.0  62.0  ...
#
# ...

# %%
food_restaurant = pd.read_csv("food_restaurant_demand_for_recon_training.csv")
food_restaurant = food_restaurant.drop(columns=["Unnamed: 0"])
food_restaurant
# Out:
#          4    13    41    42    45     48    50     79    88     90  ...  \
# 0      3.0   3.0   5.0   2.0   4.0   81.0   7.0   21.0   1.0   18.0  ...
# 1      1.0   2.0  22.0  14.0   0.0   72.0  20.0   46.0   2.0   28.0  ...
# 2      2.0   2.0  11.0   9.0   0.0   63.0  14.0   34.0   2.0   16.0  ...
# 3      3.0   0.0   3.0   7.0   1.0   31.0   5.0   19.0   1.0   13.0  ...
# 4      0.0   0.0   8.0   4.0   0.0   20.0   8.0   13.0   1.0    4.0  ...
# ...    ...   ...   ...   ...   ...    ...   ...    ...   ...    ...  ...
# 24808  2.0  37.0  27.0   4.0  12.0  140.0  26.0  104.0  19.0  100.0  ...
# 24809  5.0  37.0  12.0   1.0   7.0  128.0  19.0  126.0  14.0  103.0  ...
# 24810  3.0  27.0   4.0   4.0   7.0  161.0  26.0  158.0   7.0  147.0  ...
# 24811  9.0  14.0  12.0   4.0  11.0  175.0  24.0  201.0  12.0  156.0  ...
# 24812  8.0   9.0   2.0   4.0  11.0  141.0  17.0  181.0  11.0   97.0  ...
#
#          234    238    239  243  244    249   261   262    263  \
# ...

# %%
religious = pd.read_csv("religious_demand_for_recon_training.csv")
religious = religious.drop(columns=["Unnamed: 0"])
religious
# Out:
#          4    13    113    140    142   143   151   166  232  244  religious
# 0      3.0   3.0   17.0   19.0   37.0  11.0  22.0   9.0  2.0  2.0      125.0
# 1      1.0   2.0   21.0   14.0   47.0  13.0  22.0  10.0  6.0  3.0      139.0
# 2      2.0   2.0   15.0    7.0   24.0  10.0   8.0   5.0  8.0  3.0       84.0
# 3      3.0   0.0    2.0    2.0   12.0   1.0   5.0   1.0  1.0  1.0       28.0
# 4      0.0   0.0    2.0    2.0    7.0   3.0   1.0   0.0  1.0  2.0       18.0
# ...    ...   ...    ...    ...    ...   ...   ...   ...  ...  ...        ...
# 24808  2.0  37.0  117.0  124.0  270.0  75.0  69.0  34.0  4.0  0.0      732.0
# 24809  5.0  37.0  127.0   86.0  250.0  52.0  44.0  27.0  8.0  1.0      637.0
# 24810  3.0  27.0  127.0   71.0  290.0  33.0  22.0  26.0  3.0  0.0      602.0
# 24811  9.0  14.0  129.0   55.0  179.0  26.0  20.0  18.0  2.0  0.0      452.0
# 24812  8.0   9.0  164.0   36.0  213.0  11.0   8.0   3.0  4.0  2.0      458.0
#
# [24813 rows x 11 columns]

# %%
school = pd.read_csv("school_demand_for_recon_training.csv")
school = school.drop(columns=["Unnamed: 0"])
school
# Out:
#          13    24    41     48    75   100    113    114  116   137  ...  202  \
# 0       3.0   7.0   5.0   81.0  22.0  35.0   17.0    8.0  2.0  23.0  ...  0.0
# 1       2.0   4.0  22.0   72.0  14.0  34.0   21.0   10.0  4.0  32.0  ...  0.0
# 2       2.0   2.0  11.0   63.0  13.0  19.0   15.0   11.0  2.0  22.0  ...  1.0
# 3       0.0   2.0   3.0   31.0   7.0  12.0    2.0    8.0  5.0   6.0  ...  0.0
# 4       0.0   2.0   8.0   20.0   8.0   5.0    2.0    1.0  2.0   6.0  ...  0.0
# ...     ...   ...   ...    ...   ...   ...    ...    ...  ...   ...  ...  ...
# 24808  37.0   6.0  27.0  140.0  41.0  81.0  117.0   41.0  1.0  70.0  ...  0.0
# 24809  37.0  10.0  12.0  128.0  31.0  67.0  127.0   45.0  0.0  45.0  ...  1.0
# 24810  27.0  10.0   4.0  161.0  21.0  56.0  127.0   73.0  3.0  51.0  ...  0.0
# 24811  14.0   9.0  12.0  175.0  12.0  62.0  129.0   80.0  2.0  48.0  ...  0.0
# 24812   9.0   3.0   2.0  141.0   5.0  35.0  164.0  101.0  2.0  37.0  ...  0.0
#
# ...

# %%
school_pri = pd.read_csv("school_pri_demand_for_recon_training.csv")
school_pri = school_pri.drop(columns=["Unnamed: 0"])
school_pri
# Out:
#         137  232  school_pri
# 0      23.0  2.0       898.0
# 1      32.0  6.0       986.0
# 2      22.0  8.0       660.0
# 3       6.0  1.0       316.0
# 4       6.0  1.0       174.0
# ...     ...  ...         ...
# 24808  70.0  4.0      4502.0
# 24809  45.0  8.0      3878.0
# 24810  51.0  3.0      3444.0
# 24811  48.0  2.0      2812.0
# 24812  37.0  4.0      2328.0
#
# [24813 rows x 3 columns]

# %%
school_sec = pd.read_csv("school_sec_demand_for_recon_training.csv")
school_sec = school_sec.drop(columns=["Unnamed: 0"])
school_sec
# Out:
#          75   137    236   261  school_sec
# 0      22.0  23.0   35.0   2.0       898.0
# 1      14.0  32.0   30.0   6.0       986.0
# 2      13.0  22.0   12.0   5.0       660.0
# 3       7.0   6.0    3.0   1.0       316.0
# 4       8.0   6.0    1.0   2.0       174.0
# ...     ...   ...    ...   ...         ...
# 24808  41.0  70.0  392.0  23.0      4502.0
# 24809  31.0  45.0  275.0  26.0      3878.0
# 24810  21.0  51.0  162.0  16.0      3444.0
# 24811  12.0  48.0  108.0  12.0      2812.0
# 24812   5.0  37.0   27.0   7.0      2328.0
#
# [24813 rows x 5 columns]

# %%
school_uni = pd.read_csv("school_uni_demand_for_recon_training.csv")
school_uni = school_uni.drop(columns=["Unnamed: 0"])
school_uni
# Out:
#           48    113    114    142    164   166    238  244  school_uni
# 0       81.0   17.0    8.0   37.0   25.0   9.0   39.0  2.0       898.0
# 1       72.0   21.0   10.0   47.0   24.0  10.0   27.0  3.0       986.0
# 2       63.0   15.0   11.0   24.0   20.0   5.0   23.0  3.0       660.0
# 3       31.0    2.0    8.0   12.0   11.0   1.0   10.0  1.0       316.0
# 4       20.0    2.0    1.0    7.0    5.0   0.0    4.0  2.0       174.0
# ...      ...    ...    ...    ...    ...   ...    ...  ...         ...
# 24808  140.0  117.0   41.0  270.0  127.0  34.0  179.0  0.0      4502.0
# 24809  128.0  127.0   45.0  250.0  118.0  27.0  119.0  1.0      3878.0
# 24810  161.0  127.0   73.0  290.0   97.0  26.0   76.0  0.0      3444.0
# 24811  175.0  129.0   80.0  179.0   97.0  18.0   36.0  0.0      2812.0
# 24812  141.0  164.0  101.0  213.0   68.0   3.0   25.0  2.0      2328.0
#
# [24813 rows x 9 columns]
