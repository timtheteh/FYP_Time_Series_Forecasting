# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/MyDrive/FYP_Python_Notebooks/Data_for_School_Computer')
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)

from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))
if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Mounted at /content/drive
# Mon Mar  4 07:16:51 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import pandas as pd
import numpy as np

# %%
pip install pyarrow

# %%
weather = pd.read_parquet("combined_dd_ss_weather_additional_covariate.parquet", engine="pyarrow")
total_fair = pd.read_parquet("combined_dd_ss_total_fair_additional_covariate.parquet", engine="pyarrow")

# %%
weather
# Out:
#          time_idx            datetime  group  target  inflow_lag_0  \
# 0             167 2021-01-07 23:00:00      4     0.0          10.0
# 1             168 2021-01-08 00:00:00      4     1.0           4.0
# 2             169 2021-01-08 01:00:00      4     2.0           1.0
# 3             170 2021-01-08 02:00:00      4     0.0           1.0
# 4             171 2021-01-08 03:00:00      4     0.0           3.0
# ...           ...                 ...    ...     ...           ...
# 1631191     24808 2023-10-31 16:00:00    263   126.0         176.0
# 1631192     24809 2023-10-31 17:00:00    263   112.0         153.0
# 1631193     24810 2023-10-31 18:00:00    263    99.0         135.0
# 1631194     24811 2023-10-31 19:00:00    263    60.0         119.0
# 1631195     24812 2023-10-31 20:00:00    263    50.0         119.0
#
#          inflow_lag_1  inflow_lag_2  inflow_lag_3  outflow_lag_0  \
# 0                 8.0           1.0           1.0            5.0
# ...

# %%
total_fair
# Out:
#          time_idx            datetime  group  target  inflow_lag_0  \
# 0             167 2021-01-07 23:00:00      4     0.0          10.0
# 1             168 2021-01-08 00:00:00      4     1.0           4.0
# 2             169 2021-01-08 01:00:00      4     2.0           1.0
# 3             170 2021-01-08 02:00:00      4     0.0           1.0
# 4             171 2021-01-08 03:00:00      4     0.0           3.0
# ...           ...                 ...    ...     ...           ...
# 1631191     24808 2023-10-31 16:00:00    263   126.0         176.0
# 1631192     24809 2023-10-31 17:00:00    263   112.0         153.0
# 1631193     24810 2023-10-31 18:00:00    263    99.0         135.0
# 1631194     24811 2023-10-31 19:00:00    263    60.0         119.0
# 1631195     24812 2023-10-31 20:00:00    263    50.0         119.0
#
#          inflow_lag_1  inflow_lag_2  inflow_lag_3  outflow_lag_0  \
# 0                 8.0           1.0           1.0            5.0
# ...

# %%
weather_columns = list(weather.columns)
total_fair_columns = list(total_fair.columns)
columns_in_weather_not_in_total_fair = list(set(weather_columns) - set(total_fair_columns))
print(columns_in_weather_not_in_total_fair)
# Out:
# ['weather_main', 'wind_gust', 'wind_speed', 'rain_1h', 'temp', 'clouds_all', 'snow_3h', 'rain_3h', 'humidity', 'city_name', 'weather_description', 'snow_1h']

# %%
for col in columns_in_weather_not_in_total_fair:
  total_fair[col] = weather[col]

# %%
total_fair
# Out:
#          time_idx            datetime  group  target  inflow_lag_0  \
# 0             167 2021-01-07 23:00:00      4     0.0          10.0
# 1             168 2021-01-08 00:00:00      4     1.0           4.0
# 2             169 2021-01-08 01:00:00      4     2.0           1.0
# 3             170 2021-01-08 02:00:00      4     0.0           1.0
# 4             171 2021-01-08 03:00:00      4     0.0           3.0
# ...           ...                 ...    ...     ...           ...
# 1631191     24808 2023-10-31 16:00:00    263   126.0         176.0
# 1631192     24809 2023-10-31 17:00:00    263   112.0         153.0
# 1631193     24810 2023-10-31 18:00:00    263    99.0         135.0
# 1631194     24811 2023-10-31 19:00:00    263    60.0         119.0
# 1631195     24812 2023-10-31 20:00:00    263    50.0         119.0
#
#          inflow_lag_1  inflow_lag_2  inflow_lag_3  outflow_lag_0  \
# 0                 8.0           1.0           1.0            5.0
# ...

# %%
total_fair.to_parquet("combined_dd_ss_all_covariates.parquet", engine="pyarrow")

# %%
df = pd.read_parquet("combined_dd_ss_all_covariates.parquet", engine="pyarrow")
df
# Out:
#          time_idx            datetime  group  target  inflow_lag_0  \
# 0             167 2021-01-07 23:00:00      4     0.0          10.0
# 1             168 2021-01-08 00:00:00      4     1.0           4.0
# 2             169 2021-01-08 01:00:00      4     2.0           1.0
# 3             170 2021-01-08 02:00:00      4     0.0           1.0
# 4             171 2021-01-08 03:00:00      4     0.0           3.0
# ...           ...                 ...    ...     ...           ...
# 1631191     24808 2023-10-31 16:00:00    263   126.0         176.0
# 1631192     24809 2023-10-31 17:00:00    263   112.0         153.0
# 1631193     24810 2023-10-31 18:00:00    263    99.0         135.0
# 1631194     24811 2023-10-31 19:00:00    263    60.0         119.0
# 1631195     24812 2023-10-31 20:00:00    263    50.0         119.0
#
#          inflow_lag_1  inflow_lag_2  inflow_lag_3  outflow_lag_0  \
# 0                 8.0           1.0           1.0            5.0
# ...
